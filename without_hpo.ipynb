# %% [markdown]
# # Training without HPO

# %% [markdown]
# ## 1. Preparation

# %%
import sagemaker

sagemaker_session = sagemaker.Session()
bucket = sagemaker_session.default_bucket()
prefix = 'sagemaker/DEMO-pytorch-mnist'
role = sagemaker.get_execution_role()

# %%
from torchvision.datasets import MNIST
from torchvision import transforms

local_dir = 'data'
MNIST.mirrors = ["https://sagemaker-sample-files.s3.amazonaws.com/datasets/image/MNIST/"]
MNIST(
    local_dir,
    download=True,
    transform=transforms.Compose(
        [transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))]
    )
)
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.1307,), std=(0.3081,))
#            )

# %%
inputs = sagemaker_session.upload_data(path='data', bucket=bucket, key_prefix=prefix)

# %%
from sagemaker.pytorch import PyTorch

estimator = PyTorch(
    entry_point='mnist.py',
    role=role,
    py_version='py3',
    framework_version='1.8.0',
    instance_count=1,
    instance_type='ml.c5.2xlarge',
    hyperparameters={'epochs': 1, 'backend': 'gloo'},
    source_dir='source_dir'
)

# %% [markdown]
# ## 2. Training

# %%
estimator.fit(inputs={'training': inputs})
# Out:
# 2022-02-09 14:44:51 Starting - Starting the training job...
# 2022-02-09 14:44:53 Starting - Launching requested ML instancesProfilerReport-1644417872: InProgress
# .........
# 2022-02-09 14:46:52 Starting - Preparing the instances for training......
# 2022-02-09 14:47:52 Downloading - Downloading input data
# 2022-02-09 14:47:52 Training - Downloading the training image...
# 2022-02-09 14:48:12 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-02-09 14:48:06,781 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-02-09 14:48:06,783 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-02-09 14:48:06,792 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-02-09 14:48:13,013 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-02-09 14:48:13,799 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /opt/conda/bin/python3.6 -m pip install -r requirements.txt
# Collecting syne-tune
#   Downloading syne_tune-0.12-py3-none-any.whl (398 kB)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.6/site-packages (from syne-tune->-r requirements.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.6/site-packages (from syne-tune->-r requirements.txt (line 1)) (1.17.30)
# Collecting sagemaker>=2.32.0
#   Downloading sagemaker-2.75.1.tar.gz (511 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.6/site-packages (from syne-tune->-r requirements.txt (line 1)) (1.1.5)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.6/site-packages (from syne-tune->-r requirements.txt (line 1)) (1.19.1)
# Collecting pytest
#   Downloading pytest-7.0.0-py3-none-any.whl (296 kB)
# Requirement already satisfied: dill in /opt/conda/lib/python3.6/site-packages (from syne-tune->-r requirements.txt (line 1)) (0.3.3)
# Collecting ujson
#   Downloading ujson-4.3.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (216 kB)
# Requirement already satisfied: PyYaml in /opt/conda/lib/python3.6/site-packages (from syne-tune->-r requirements.txt (line 1)) (5.4.1)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.6/site-packages (from sagemaker>=2.32.0->syne-tune->-r requirements.txt (line 1)) (20.3.0)
# Collecting boto3
#   Downloading boto3-1.20.51-py3-none-any.whl (131 kB)
# Requirement already satisfied: google-pasta in /opt/conda/lib/python3.6/site-packages (from sagemaker>=2.32.0->syne-tune->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: protobuf>=3.1 in /opt/conda/lib/python3.6/site-packages (from sagemaker>=2.32.0->syne-tune->-r requirements.txt (line 1)) (3.15.6)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /opt/conda/lib/python3.6/site-packages (from sagemaker>=2.32.0->syne-tune->-r requirements.txt (line 1)) (0.1.5)
# Requirement already satisfied: smdebug_rulesconfig==1.0.1 in /opt/conda/lib/python3.6/site-packages (from sagemaker>=2.32.0->syne-tune->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /opt/conda/lib/python3.6/site-packages (from sagemaker>=2.32.0->syne-tune->-r requirements.txt (line 1)) (3.7.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.6/site-packages (from sagemaker>=2.32.0->syne-tune->-r requirements.txt (line 1)) (20.9)
# Collecting pathos
#   Downloading pathos-0.2.8-py2.py3-none-any.whl (81 kB)
# Collecting botocore<1.24.0,>=1.23.51
#   Downloading botocore-1.23.51-py3-none-any.whl (8.5 MB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.1-py3-none-any.whl (79 kB)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.6/site-packages (from boto3->syne-tune->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.6/site-packages (from botocore<1.24.0,>=1.23.51->boto3->syne-tune->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.6/site-packages (from botocore<1.24.0,>=1.23.51->boto3->syne-tune->-r requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker>=2.32.0->syne-tune->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging>=20.0->sagemaker>=2.32.0->syne-tune->-r requirements.txt (line 1)) (2.4.7)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker>=2.32.0->syne-tune->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.6/site-packages (from pandas->syne-tune->-r requirements.txt (line 1)) (2021.1)
# Collecting pox>=0.3.0
#   Downloading pox-0.3.0-py2.py3-none-any.whl (30 kB)
# Collecting multiprocess>=0.70.12
#   Downloading multiprocess-0.70.12.2-py36-none-any.whl (106 kB)
# Collecting ppft>=1.6.6.4
#   Downloading ppft-1.6.6.4-py3-none-any.whl (65 kB)
# Collecting dill
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting py>=1.8.2
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
# Collecting tomli>=1.0.0
#   Downloading tomli-1.2.3-py3-none-any.whl (12 kB)
# Building wheels for collected packages: sagemaker
#   Building wheel for sagemaker (setup.py): started
#   Building wheel for sagemaker (setup.py): finished with status 'done'
#   Created wheel for sagemaker: filename=sagemaker-2.75.1-py2.py3-none-any.whl size=709416 sha256=ce5a220b37c1ec2422c03ecb3137b3f8f9947d65f5aa0e273b11145b5b64e12e
#   Stored in directory: /root/.cache/pip/wheels/04/4e/04/ad25d8866c9738524d659f5e88015dba26ebd28ced7bb8c799
# Successfully built sagemaker
# Installing collected packages: dill, botocore, s3transfer, ppft, pox, multiprocess, tomli, py, pluggy, pathos, iniconfig, boto3, ujson, sagemaker, pytest, syne-tune
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.3
#     Uninstalling dill-0.3.3:
#       Successfully uninstalled dill-0.3.3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.20.30
#     Uninstalling botocore-1.20.30:
#       Successfully uninstalled botocore-1.20.30
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.3.4
#     Uninstalling s3transfer-0.3.4:
#       Successfully uninstalled s3transfer-0.3.4
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.17.30
#     Uninstalling boto3-1.17.30:
#       Successfully uninstalled boto3-1.17.30
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 2.30.0
#     Uninstalling sagemaker-2.30.0:
#       Successfully uninstalled sagemaker-2.30.0
# Successfully installed boto3-1.20.51 botocore-1.23.51 dill-0.3.4 iniconfig-1.1.1 multiprocess-0.70.12.2 pathos-0.2.8 pluggy-1.0.0 pox-0.3.0 ppft-1.6.6.4 py-1.11.0 pytest-7.0.0 s3transfer-0.5.1 sagemaker-2.75.1 syne-tune-0.12 tomli-1.2.3 ujson-4.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# awscli 1.19.30 requires botocore==1.20.30, but you have botocore 1.23.51 which is incompatible.
# awscli 1.19.30 requires s3transfer<0.4.0,>=0.3.0, but you have s3transfer 0.5.1 which is incompatible.
# 2022-02-09 14:48:21,022 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-02-09 14:48:21,035 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-02-09 14:48:21,045 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-02-09 14:48:21,054 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "backend": "gloo",
#         "epochs": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2022-02-09-14-44-32-359",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-1-861558531758/pytorch-training-2022-02-09-14-44-32-359/source/sourcedir.tar.gz",
#     "module_name": "mnist",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"backend":"gloo","epochs":1}
# SM_USER_ENTRY_POINT=mnist.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=mnist
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-1-861558531758/pytorch-training-2022-02-09-14-44-32-359/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"backend":"gloo","epochs":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2022-02-09-14-44-32-359","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-1-861558531758/pytorch-training-2022-02-09-14-44-32-359/source/sourcedir.tar.gz","module_name":"mnist","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"mnist.py"}
# SM_USER_ARGS=["--backend","gloo","--epochs","1"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BACKEND=gloo
# SM_HP_EPOCHS=1
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 mnist.py --backend gloo --epochs 1
# Distributed training - False
# Number of gpus available - 0
# Get train data loader
# Get test data loader
# Processes 60000/60000 (100%) of train data
# Processes 10000/10000 (100%) of test data
# [2022-02-09 14:48:22.734 algo-1:42 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-02-09 14:48:22.924 algo-1:42 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2022-02-09 14:48:22.925 algo-1:42 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-02-09 14:48:22.925 algo-1:42 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-02-09 14:48:22.925 algo-1:42 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2022-02-09 14:48:22.925 algo-1:42 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-02-09 14:48:22.965 algo-1:42 INFO hook.py:584] name:module.conv1.weight count_params:250
# [2022-02-09 14:48:22.965 algo-1:42 INFO hook.py:584] name:module.conv1.bias count_params:10
# [2022-02-09 14:48:22.965 algo-1:42 INFO hook.py:584] name:module.conv2.weight count_params:5000
# [2022-02-09 14:48:22.965 algo-1:42 INFO hook.py:584] name:module.conv2.bias count_params:20
# [2022-02-09 14:48:22.965 algo-1:42 INFO hook.py:584] name:module.fc1.weight count_params:16000
# [2022-02-09 14:48:22.965 algo-1:42 INFO hook.py:584] name:module.fc1.bias count_params:50
# [2022-02-09 14:48:22.965 algo-1:42 INFO hook.py:584] name:module.fc2.weight count_params:500
# [2022-02-09 14:48:22.965 algo-1:42 INFO hook.py:584] name:module.fc2.bias count_params:10
# [2022-02-09 14:48:22.965 algo-1:42 INFO hook.py:586] Total Trainable Params: 21840
# [2022-02-09 14:48:22.965 algo-1:42 INFO hook.py:413] Monitoring the collections: losses
# [2022-02-09 14:48:22.968 algo-1:42 INFO hook.py:476] Hook is writing from the hook with pid: 42
# Train Epoch: 1 [6400/60000 (11%)] Loss: 2.010908
# Train Epoch: 1 [12800/60000 (21%)] Loss: 1.009527
# Train Epoch: 1 [19200/60000 (32%)] Loss: 0.877578
# Train Epoch: 1 [25600/60000 (43%)] Loss: 0.805486
# Train Epoch: 1 [32000/60000 (53%)] Loss: 0.635695
# Train Epoch: 1 [38400/60000 (64%)] Loss: 0.505831
# Train Epoch: 1 [44800/60000 (75%)] Loss: 0.537033
# Train Epoch: 1 [51200/60000 (85%)] Loss: 0.532630
# Train Epoch: 1 [57600/60000 (96%)] Loss: 0.428416
# Test set: Average loss: 0.1919, Accuracy: 9424/10000 (94%)
# [tune-metric]: {"test_loss": 0.19189317474365233, "st_worker_timestamp": 1644418115.5007532, "st_worker_time": 12.941544877000013, "st_worker_iter": 0}
# Saving the model.
# DEBUG:__main__:Distributed training - False
# DEBUG:__main__:Number of gpus available - 0
# INFO:__main__:Get train data loader
# INFO:__main__:Get test data loader
# DEBUG:__main__:Processes 60000/60000 (100%) of train data
# DEBUG:__main__:Processes 10000/10000 (100%) of test data
# INFO:__main__:Train Epoch: 1 [6400/60000 (11%)] Loss: 2.010908
# INFO:__main__:Train Epoch: 1 [12800/60000 (21%)] Loss: 1.009527
# INFO:__main__:Train Epoch: 1 [19200/60000 (32%)] Loss: 0.877578
# INFO:__main__:Train Epoch: 1 [25600/60000 (43%)] Loss: 0.805486
# INFO:__main__:Train Epoch: 1 [32000/60000 (53%)] Loss: 0.635695
# INFO:__main__:Train Epoch: 1 [38400/60000 (64%)] Loss: 0.505831
# INFO:__main__:Train Epoch: 1 [44800/60000 (75%)] Loss: 0.537033
# INFO:__main__:Train Epoch: 1 [51200/60000 (85%)] Loss: 0.532630
# INFO:__main__:Train Epoch: 1 [57600/60000 (96%)] Loss: 0.428416
# /opt/conda/lib/python3.6/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# INFO:__main__:Test set: Average loss: 0.1919, Accuracy: 9424/10000 (94%)
# INFO:__main__:Saving the model.
# 2022-02-09 14:48:35,662 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2022-02-09 14:48:52 Uploading - Uploading generated training model
# 2022-02-09 14:48:52 Completed - Training job completed
# Training seconds: 67
# Billable seconds: 67
